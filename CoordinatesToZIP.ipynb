         print(f"Warning: Incorrect format on line {i+1}: '{line}' - Skipping")

# --- Perform Reverse Geocoding ---
results = []
print(f"Processing {len(coordinates)} coordinates (approx. 1 per second)...")

for i, (lat, lon) in enumerate(coordinates):
    zip_code = "Not Found"
    found_zip = False
    request_start_time = time.time()

    try:
        coordinate_str = f"{lat}, {lon}"
        locations = geolocator.reverse(coordinate_str, exactly_one=False, language='en', timeout=15)

        if locations:
            for location in locations:
                if location and location.raw and 'address' in location.raw:
                    potential_zip = location.raw['address'].get('postcode')
                    if potential_zip:
                        zip_code = potential_zip
                        found_zip = True
                        break

        results.append({'latitude': lat, 'longitude': lon, 'zip_code': zip_code})
        status = "(Found in nearby results)" if found_zip and zip_code != "Not Found" else ""
        print(f"{i+1}/{len(coordinates)}: Coords ({lat}, {lon}) -> ZIP: {zip_code} {status}")

    except GeocoderTimedOut:
        print(f"Error: Geocoder timed out for ({lat}, {lon}). Skipping.")
        results.append({'latitude': lat, 'longitude': lon, 'zip_code': 'Timeout Error'})
    except GeocoderServiceError as e:
        print(f"Error: Geocoder service error for ({lat}, {lon}): {e}. Skipping.")
        results.append({'latitude': lat, 'longitude': lon, 'zip_code': f'Service Error: {e}'})
    except Exception as e:
        print(f"Error: An unexpected error occurred for ({lat}, {lon}): {e}. Skipping.")
        results.append({'latitude': lat, 'longitude': lon, 'zip_code': f'Unknown Error: {e}'})
    finally:
        elapsed_time = time.time() - request_start_time
        sleep_time = max(0, 1.0 - elapsed_time)
        time.sleep(sleep_time)

print("\n--- Geocoding Complete ---")

# --- Export Results to CSV ---
# *** MODIFIED LINE TO SPECIFY DOWNLOADS FOLDER ***
output_filename = ''

fieldnames = ['latitude', 'longitude', 'zip_code']
print(f"\nAttempting to save results to {output_filename}...")
try:
    with open(output_filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(results)
    print(f"Successfully saved results to {output_filename}")
except IOError as e:
    # This could still happen if permissions for the Downloads folder are wrong
    print(f"\nError: Could not write results to CSV file '{output_filename}'. Reason: {e}")
except Exception as e:
     print(f"\nError: An unexpected error occurred during CSV writing. Reason: {e}")
# Out:
# Processing 232 coordinates (approx. 1 per second)...
# 1/232: Coords (33.1427, -81.7625) -> ZIP: 30830 (Found in nearby results)
# 2/232: Coords (34.1256, -84.9222) -> ZIP: 30120 (Found in nearby results)
# 3/232: Coords (34.7939, -83.5402) -> ZIP: 30523 (Found in nearby results)
# 4/232: Coords (31.6026, -84.137) -> ZIP: 31701 (Found in nearby results)
# 5/232: Coords (33.8239, -84.4758) -> ZIP: 30369 (Found in nearby results)
# 6/232: Coords (33.3207, -83.8414) -> ZIP: Not Found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 273
#     271 try:
#     272     coordinate_str = f"{lat}, {lon}"
# --> 273     locations = geolocator.reverse(coordinate_str, exactly_one=False, language='en', timeout=15)
#     275     if locations:
#     276         for location in locations:
#
# ...
